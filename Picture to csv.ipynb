# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/1.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/1.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/2.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/2.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/3.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/3.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/4.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/4.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/5.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/5.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/6.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/6.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/7.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/7.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/8.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/8.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/9.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/9.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/10.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/10.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/11.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/11.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/12.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/12.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/13.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/13.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/14.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/14.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/15.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/15.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/16.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/16.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/17.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/17.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/18.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/18.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/19.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/19.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/20.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/20.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/21.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/21.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/22.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/22.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/23.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/23.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/24.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/24.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/25.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/25.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/26.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/26.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/27.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/27.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/28.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/28.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/29.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/29.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/30.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/30.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/31.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/31.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/32.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/32.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/33.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/33.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/34.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/34.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/35.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/35.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/36.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/36.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/37.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/37.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/38.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/38.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/39.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/39.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/40.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/40.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/41.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/41.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/42.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/42.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/43.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/43.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/44.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/44.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/45.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/45.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/46.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/46.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/47.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/47.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/48.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/48.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/49.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/49.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/50.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/50.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/51.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/51.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/52.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/52.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/53.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/53.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/54.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/54.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/55.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/55.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/56.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/56.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/57.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/57.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/58.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/58.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/59.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/59.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/60.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/60.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/61.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/61.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/62.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/62.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/63.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/63.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/64.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/64.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/65.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/65.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/66.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/66.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/67.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/67.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/68.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/68.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/69.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/69.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/70.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/70.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/71.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/71.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/72.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/72.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/73.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/73.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/74.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/74.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/75.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/75.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/76.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/76.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/77.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/77.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/78.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/78.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/79.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/79.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/80.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/80.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/81.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/81.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/82.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/82.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/83.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/83.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/84.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/84.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/85.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/85.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/86.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/86.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/87.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/87.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/88.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/88.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/89.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/89.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/90.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/90.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/91.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/91.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/92.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/92.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/93.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/93.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/94.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/94.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/95.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/95.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/96.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/96.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/97.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/97.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/98.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/98.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/99.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/99.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df

# %%
import requests
from PIL import Image
from io import BytesIO
import numpy
import matplotlib.pyplot as plt
import pandas as pd

image_paths = "coat/100.png"

img = Image.open(image_paths).convert(mode="L")
img = img.resize((28, 28))
# img = img * 255
x = (255 - numpy.expand_dims(numpy.array(img), -1))
plt.imshow(x.squeeze ( - 1), cmap="gray")
np_imge = numpy.array(x.squeeze ( - 1))
# print(np_imge)
#rubah array jadi csv
#save csv
data = np_imge.tofile('csvcoat/100.csv', sep = ',')
# df = pd.read_csv('data1.csv')
# df
